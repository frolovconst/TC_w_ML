# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def sta_compare_with_avg(flow_data, flow_avg, station_no, chrstc_to_plot = 'Avg Speed'):
    if not np.isin('Time', flow_data.columns):
        flow_data['Time'] = flow_data.Timestamp.dt.time
#     if not np.isin('Time', flow_data2.columns):
#         flow_data2['Time'] = flow_data2.Timestamp.dt.time
    ax = flow_data[flow_data.Station==station_no].plot(x='Time', y='Avg Speed', figsize=[15,10], label=flow_data.Timestamp.dt.day[0])
    flow_avg[flow_avg.Station==station_no].plot(x='Time', y='Avg Speed', ax=ax, label='avg')
    plt.grid()
    plt.show()

# %%
gb = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/monays_till_apr.csv', parse_dates=['Time'])

gb['Time'] = gb.Time.dt.time

# %%
dct = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/monays_till_apr_dct.csv')

# %%
dct.shape
# Out:
# (2585, 2)

# %%
srs = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Jan/smoothed/d07_text_station_5min_2017_01_09.tx.csv', parse_dates=[0])

# %%
srs2 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Jan/smoothed/d07_text_station_5min_2017_01_23.tx.csv', parse_dates=[0])

# %%
srs3 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Jan/smoothed/d07_text_station_5min_2017_01_30.tx.csv', parse_dates=[0])

# %%
srs4 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Feb/smoothed/d07_text_station_5min_2017_02_06.tx.csv', parse_dates=[0])

# %%
srs5 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Feb/smoothed/d07_text_station_5min_2017_02_13.tx.csv', parse_dates=[0])

# %%
srs6 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Feb/smoothed/d07_text_station_5min_2017_02_20.tx.csv', parse_dates=[0])

# %%
srs7 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Feb/smoothed/d07_text_station_5min_2017_02_27.tx.csv', parse_dates=[0])

# %%
srs8 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Mar/smoothed/d07_text_station_5min_2017_03_06.tx.csv', parse_dates=[0])

# %%
srs9 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Mar/smoothed/d07_text_station_5min_2017_03_13.tx.csv', parse_dates=[0])

# %%
srs10 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Mar/smoothed/d07_text_station_5min_2017_03_20.tx.csv', parse_dates=[0])

# %%
srs11 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Mar/smoothed/d07_text_station_5min_2017_03_27.tx.csv', parse_dates=[0])

# %%
srs12 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Apr/smoothed/d07_text_station_5min_2017_04_03.tx.csv')
srs13 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Apr/smoothed/d07_text_station_5min_2017_04_10.tx.csv')
srs14 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Apr/smoothed/d07_text_station_5min_2017_04_17.tx.csv')
srs15 = pd.read_csv('/home/frolovconst/Dvlpt/prj/Python/tc_w_ml/data/PeMS/Series/Batch/light/Apr/smoothed/d07_text_station_5min_2017_04_24.tx.csv')

# %%
srs.head(10)
# Out:
#             Timestamp  Station  District  Freeway Direction of Travel  \
# 0 2017-01-09 00:20:00   715898         7        5                   S
# 1 2017-01-09 00:20:00   715918         7        5                   N
# 2 2017-01-09 00:20:00   715920         7        5                   S
# 3 2017-01-09 00:20:00   715929         7        5                   S
# 4 2017-01-09 00:20:00   715930         7        5                   N
# 5 2017-01-09 00:20:00   715933         7        5                   N
# 6 2017-01-09 00:20:00   715938         7        5                   N
# 7 2017-01-09 00:20:00   715944         7        5                   N
# 8 2017-01-09 00:20:00   715947         7        5                   S
# 9 2017-01-09 00:20:00   715996         7        5                   S
#
#   Lane Type  Station Length  Samples  % Observed  Total Flow  Avg Occupancy  \
# 0        ML           0.430        0           0        80.0         0.0113
# ...

# %%
sta_compare_with_avg(srs, gb, 715938)

# %%
sta_compare_with_avg(srs2, gb, 715938)

# %%
sta_compare_with_avg(srs3, gb, 715938)

# %%
sta_compare_with_avg(srs4, gb, 715938)

# %%
sta_compare_with_avg(srs5, gb, 715938)

# %%
sta_compare_with_avg(srs6, gb, 715938)

# %%
sta_compare_with_avg(srs7, gb, 715938)

# %%
sta_compare_with_avg(srs8, gb, 715938)

# %%
sta_compare_with_avg(srs9, gb, 715938)

# %%
sta_compare_with_avg(srs10, gb, 715938)

# %%
sta_compare_with_avg(srs11, gb, 715938)

# %%
sta_compare_with_avg(srs12, gb, 715938)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _make_dt_accessor(self)
#    2819         try:
# -> 2820             return maybe_to_datetimelike(self)
#    2821         except Exception:
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in maybe_to_datetimelike(data, copy)
#      83     raise TypeError("cannot convert an object of type {0} to a "
# ---> 84                     "datetimelike index".format(type(data)))
#      85
#
# TypeError: cannot convert an object of type <class 'pandas.core.series.Series'> to a datetimelike index
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-c8aa20c4c8ac> in <module>()
# ----> 1 sta_compare_with_avg(srs12, gb, 715938)
#
# ...

# %%
sta_compare_with_avg(srs13, gb, 715938)

# %%
sta_compare_with_avg(srs14, gb, 715938)
